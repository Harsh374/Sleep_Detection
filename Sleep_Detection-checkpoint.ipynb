# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(rescale=1./255,
                                    validation_split=0.3
                                   )

# %%
classes = ["sleeping", "not sleeping"]

train = data_generator.flow_from_directory(
r"C:\Users\harsh\Desktop\Sleep_Detection",
target_size = (128,128),
classes=classes,
batch_size=20,
class_mode='categorical',
subset="training"
)

val = data_generator.flow_from_directory(
r"C:\Users\harsh\Desktop\Sleep_Detection",
target_size = (128,128),
classes=classes,
batch_size=20,
class_mode='categorical',
subset="validation"
)
# Out:
# Found 52 images belonging to 2 classes.
# Found 21 images belonging to 2 classes.

# %%
x_train, y_train = next(train)
x_val, y_val = next(val)

print(x_train[0].shape)
plt.imshow(x_train[0])
plt.show()
# Out:
# (128, 128, 3)

# %%
tf.keras.backend.clear_session()

model = Sequential([
    Conv2D(64, 7, activation="relu", padding="same",
                       input_shape=(128,128,3)),
    MaxPool2D(2),
    Conv2D(128, 5, activation="relu", padding="same"),
    #Conv2D(128, 3, activation="relu", padding="same"),
    MaxPool2D(2),
    #Conv2D(256, 3, activation="relu", padding="same"),
    Conv2D(128, 3, activation="relu", padding="same"),
    MaxPool2D(2),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dense(2, activation="softmax")
])
model.layers[0].trainable = False

model.compile(
    loss="categorical_crossentropy", 
    optimizer=Adam(learning_rate=1e-5), 
    metrics=["accuracy"]
)

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# C:\Users\harsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 64)        │           9,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,564,802 (17.41 MB)
#  Trainable params: 4,555,330 (17.38 MB)
#  Non-trainable params: 9,472 (37.00 KB)

# %%
checkpoint = ModelCheckpoint("model1.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
lr_callbacks = [checkpoint]

# %%
epochs=30
hist = model.fit(train,
                 epochs=epochs,
                 callbacks=lr_callbacks,
                 validation_data=val,)
# Out:
# Epoch 1/30
# C:\Users\harsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.4308 - loss: 0.6943
# Epoch 1: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - accuracy: 0.4337 - loss: 0.6949 - val_accuracy: 0.5714 - val_loss: 0.6910
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5123 - loss: 0.6977
# Epoch 2: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.5236 - loss: 0.6960 - val_accuracy: 0.5714 - val_loss: 0.6898
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6029 - loss: 0.6947
# Epoch 3: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.6012 - loss: 0.6950 - val_accuracy: 0.6667 - val_loss: 0.6889
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4826 - loss: 0.6866
# Epoch 4: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 0.4870 - loss: 0.6878 - val_accuracy: 0.4762 - val_loss: 0.6889
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7011 - loss: 0.6859
# Epoch 5: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.6845 - loss: 0.6875 - val_accuracy: 0.4762 - val_loss: 0.6891
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5186 - loss: 0.6951
# Epoch 6: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5091 - loss: 0.6963 - val_accuracy: 0.4762 - val_loss: 0.6892
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7102 - loss: 0.6876
# Epoch 7: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - accuracy: 0.6721 - loss: 0.6907 - val_accuracy: 0.3810 - val_loss: 0.6888
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6340 - loss: 0.6814
# Epoch 8: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.6197 - loss: 0.6815 - val_accuracy: 0.3810 - val_loss: 0.6886
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6365 - loss: 0.6693
# Epoch 9: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.6361 - loss: 0.6701 - val_accuracy: 0.4286 - val_loss: 0.6885
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7141 - loss: 0.6765
# Epoch 10: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.7087 - loss: 0.6759 - val_accuracy: 0.3810 - val_loss: 0.6882
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5926 - loss: 0.6707
# Epoch 11: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.5983 - loss: 0.6711 - val_accuracy: 0.4762 - val_loss: 0.6885
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.6189 - loss: 0.6719
# Epoch 12: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 0.6132 - loss: 0.6729 - val_accuracy: 0.5238 - val_loss: 0.6885
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6740 - loss: 0.6732
# Epoch 13: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.6642 - loss: 0.6740 - val_accuracy: 0.5238 - val_loss: 0.6877
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5929 - loss: 0.6831
# Epoch 14: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.6082 - loss: 0.6818 - val_accuracy: 0.5238 - val_loss: 0.6870
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6293 - loss: 0.6685
# Epoch 15: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.6210 - loss: 0.6686 - val_accuracy: 0.5714 - val_loss: 0.6864
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5904 - loss: 0.6806
# Epoch 16: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.5918 - loss: 0.6805 - val_accuracy: 0.5238 - val_loss: 0.6855
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6635 - loss: 0.6651
# Epoch 17: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 0.6514 - loss: 0.6667 - val_accuracy: 0.5714 - val_loss: 0.6849
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5968 - loss: 0.6758
# Epoch 18: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.6014 - loss: 0.6768 - val_accuracy: 0.6190 - val_loss: 0.6852
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6244 - loss: 0.6741
# Epoch 19: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.6365 - loss: 0.6723 - val_accuracy: 0.6190 - val_loss: 0.6850
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6636 - loss: 0.6665
# Epoch 20: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.6564 - loss: 0.6669 - val_accuracy: 0.6190 - val_loss: 0.6847
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7396 - loss: 0.6404
# Epoch 21: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 0.7422 - loss: 0.6415 - val_accuracy: 0.5714 - val_loss: 0.6844
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6803 - loss: 0.6268
# Epoch 22: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 0.6689 - loss: 0.6318 - val_accuracy: 0.5238 - val_loss: 0.6842
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6931 - loss: 0.6513
# Epoch 23: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - accuracy: 0.6881 - loss: 0.6520 - val_accuracy: 0.4762 - val_loss: 0.6832
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7873 - loss: 0.6209
# Epoch 24: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.7732 - loss: 0.6242 - val_accuracy: 0.5238 - val_loss: 0.6821
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5366 - loss: 0.6865
# Epoch 25: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.5419 - loss: 0.6849 - val_accuracy: 0.5238 - val_loss: 0.6814
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7603 - loss: 0.6435
# Epoch 26: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.7529 - loss: 0.6446 - val_accuracy: 0.5714 - val_loss: 0.6812
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5871 - loss: 0.6612
# Epoch 27: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.5942 - loss: 0.6604 - val_accuracy: 0.7143 - val_loss: 0.6810
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7019 - loss: 0.6595
# Epoch 28: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.7091 - loss: 0.6583 - val_accuracy: 0.7143 - val_loss: 0.6805
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7182 - loss: 0.6575
# Epoch 29: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.7310 - loss: 0.6537 - val_accuracy: 0.7143 - val_loss: 0.6803
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8462 - loss: 0.6243
# Epoch 30: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.8317 - loss: 0.6279 - val_accuracy: 0.7143 - val_loss: 0.6800

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_json = model.to_json()
with open("model_a2.json","w") as json_file:
    json_file.write(model_json)
